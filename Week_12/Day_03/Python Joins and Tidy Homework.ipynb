# %%
pip install pyjanitor
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 158.4/158.4 kB 2.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script natsort.exe is installed in 'C:\Users\Kirsty\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
from janitor import clean_names

# %% [markdown]
# #### 1. Load data

# %%
pwd
# Out:
# 'C:\\Users\\Kirsty\\Documents\\GitHub\\codeclan_homework_Kirsty\\Week_12\\Day_03'

# %%
card_base = pd.read_csv("C:/Users/Kirsty/Documents/GitHub/codeclan_homework_Kirsty/Week_12/Day_03/data/CardBase.csv").clean_names()
customer_base = pd.read_csv("C:/Users/Kirsty/Documents/GitHub/codeclan_homework_Kirsty/Week_12/Day_03/data/CustomerBase.csv").clean_names()
fraud_base = pd.read_csv("C:/Users/Kirsty/Documents/GitHub/codeclan_homework_Kirsty/Week_12/Day_03/data/FraudBase.csv").clean_names()
transaction_base = pd.read_csv("C:/Users/Kirsty/Documents/GitHub/codeclan_homework_Kirsty/Week_12/Day_03/data/TransactionBase.csv").clean_names()

# %% [markdown]
# #### 2. Join `card_base` and `customer_base`

# %%
card_base
# Out:
#              card_number card_family  credit_limit  cust_id
# 0    8638-5407-3631-8196     Premium        530000  CC67088
# 1    7106-4239-7093-1515        Gold         18000  CC12076
# 2    6492-5655-8241-3530     Premium        596000  CC97173
# 3    2868-5606-5152-5706        Gold         27000  CC55858
# 4    1438-6906-2509-8219    Platinum        142000  CC90518
# ..                   ...         ...           ...      ...
# 495  4708-4407-9601-6022     Premium        691000  CC64993
# 496  6042-2856-7280-2925        Gold         33000  CC26787
# 497  8706-3809-5167-3899     Premium        144000  CC32532
# 498  9540-8558-5897-5046     Premium        830000  CC90246
# 499  5587-7265-8118-7718        Gold         24000  CC37803
#
# [500 rows x 4 columns]

# %%
customer_base
# Out:
#       cust_id  age customer_segment customer_vintage_group
# 0     CC25034   35          Diamond                    VG1
# 1     CC59625   22          Diamond                    VG1
# 2     CC69314   33          Diamond                    VG1
# 3     CC67036   46          Diamond                    VG1
# 4     CC25597   44          Diamond                    VG1
# ...       ...  ...              ...                    ...
# 5669  CC53430   27         Platinum                    VG2
# 5670  CC31823   33         Platinum                    VG2
# 5671  CC15335   28         Platinum                    VG2
# 5672  CC81556   26         Platinum                    VG2
# 5673  CC38634   21         Platinum                    VG2
#
# [5674 rows x 4 columns]

# %%
card_customers = card_base.merge(customer_base, how = "inner", on = "cust_id").copy()


card_customers
# Out:
#              card_number card_family  credit_limit  cust_id  age  \
# 0    8638-5407-3631-8196     Premium        530000  CC67088   27
# 1    7106-4239-7093-1515        Gold         18000  CC12076   48
# 2    6492-5655-8241-3530     Premium        596000  CC97173   22
# 3    2868-5606-5152-5706        Gold         27000  CC55858   30
# 4    1438-6906-2509-8219    Platinum        142000  CC90518   50
# ..                   ...         ...           ...      ...  ...
# 495  4708-4407-9601-6022     Premium        691000  CC64993   34
# 496  6042-2856-7280-2925        Gold         33000  CC26787   46
# 497  8706-3809-5167-3899     Premium        144000  CC32532   28
# 498  9540-8558-5897-5046     Premium        830000  CC90246   35
# 499  5587-7265-8118-7718        Gold         24000  CC37803   21
#
#     customer_segment customer_vintage_group
# 0            Diamond                    VG1
# 1               Gold                    VG3
# 2            Diamond                    VG1
# ...

# %% [markdown]
#  #### 3. Join `fraud_base` and `transaction_base`

# %%
fraud_base
# Out:
#     transaction_id  fraud_flag
# 0     CTID50558449           1
# 1     CTID55936882           1
# 2     CTID63762180           1
# 3     CTID76723439           1
# 4     CTID21246201           1
# ..             ...         ...
# 104   CTID57993591           1
# 105   CTID91108283           1
# 106   CTID30494187           1
# 107   CTID51301522           1
# 108   CTID49517337           1
#
# [109 rows x 2 columns]

# %%
transaction_base
# Out:
#      transaction_id transaction_date       credit_card_id  transaction_value  \
# 0      CTID28830551        24-Apr-16  1629-9566-3285-2123              23649
# 1      CTID45504917        11-Feb-16  3697-6001-4909-5350              26726
# 2      CTID47312290         1-Nov-16  5864-4475-3659-1440              22012
# 3      CTID25637718        28-Jan-16  5991-4421-8476-3804              37637
# 4      CTID66743960        17-Mar-16  1893-8853-9900-8478               5113
# ...             ...              ...                  ...                ...
# 9995   CTID25037573        10-Jun-16  9157-2802-8374-1145              44280
# 9996   CTID43832298        23-May-16  7416-4529-6690-5703              27163
# 9997   CTID56532072         6-Aug-16  6699-2639-4522-6219              36424
# 9998   CTID88101446        10-Oct-16  8341-5263-4582-7396               8464
# 9999   CTID64730271        18-Jun-16  1947-8602-1695-7503               7606
#
#      transaction_segment
# ...

# %%
fraud_transactions = fraud_base.merge(transaction_base, how = "outer", on = "transaction_id").copy()

fraud_transactions
# Out:
#      transaction_id  fraud_flag transaction_date       credit_card_id  \
# 0      CTID50558449         1.0         6-May-16  4246-1369-3659-8804
# 1      CTID55936882         1.0        29-Nov-16  1336-9200-1264-2551
# 2      CTID63762180         1.0         5-Dec-16  8528-6154-7390-5081
# 3      CTID76723439         1.0        15-Sep-16  7908-2695-7391-7499
# 4      CTID21246201         1.0        29-Feb-16  2524-4184-5908-6750
# ...             ...         ...              ...                  ...
# 9995   CTID25037573         NaN        10-Jun-16  9157-2802-8374-1145
# 9996   CTID43832298         NaN        23-May-16  7416-4529-6690-5703
# 9997   CTID56532072         NaN         6-Aug-16  6699-2639-4522-6219
# 9998   CTID88101446         NaN        10-Oct-16  8341-5263-4582-7396
# 9999   CTID64730271         NaN        18-Jun-16  1947-8602-1695-7503
#
#       transaction_value transaction_segment
# 0                  6984               SEG23
# ...

# %% [markdown]
# The resulting row number tells us that all rows in the `fraud_base` dataset match atleast one row in the `transaction_base` dataset, otherwise we would have more rows than in the original `transaction_base` dataset.

# %% [markdown]
# #### 4. Join `card_base` and `transaction_base`

# %%
card_base
# Out:
#              card_number card_family  credit_limit  cust_id
# 0    8638-5407-3631-8196     Premium        530000  CC67088
# 1    7106-4239-7093-1515        Gold         18000  CC12076
# 2    6492-5655-8241-3530     Premium        596000  CC97173
# 3    2868-5606-5152-5706        Gold         27000  CC55858
# 4    1438-6906-2509-8219    Platinum        142000  CC90518
# ..                   ...         ...           ...      ...
# 495  4708-4407-9601-6022     Premium        691000  CC64993
# 496  6042-2856-7280-2925        Gold         33000  CC26787
# 497  8706-3809-5167-3899     Premium        144000  CC32532
# 498  9540-8558-5897-5046     Premium        830000  CC90246
# 499  5587-7265-8118-7718        Gold         24000  CC37803
#
# [500 rows x 4 columns]

# %%
transaction_base
# Out:
#      transaction_id transaction_date       credit_card_id  transaction_value  \
# 0      CTID28830551        24-Apr-16  1629-9566-3285-2123              23649
# 1      CTID45504917        11-Feb-16  3697-6001-4909-5350              26726
# 2      CTID47312290         1-Nov-16  5864-4475-3659-1440              22012
# 3      CTID25637718        28-Jan-16  5991-4421-8476-3804              37637
# 4      CTID66743960        17-Mar-16  1893-8853-9900-8478               5113
# ...             ...              ...                  ...                ...
# 9995   CTID25037573        10-Jun-16  9157-2802-8374-1145              44280
# 9996   CTID43832298        23-May-16  7416-4529-6690-5703              27163
# 9997   CTID56532072         6-Aug-16  6699-2639-4522-6219              36424
# 9998   CTID88101446        10-Oct-16  8341-5263-4582-7396               8464
# 9999   CTID64730271        18-Jun-16  1947-8602-1695-7503               7606
#
#      transaction_segment
# ...

# %%
# this creates a column called `in_both` by checking if `card_number` is in the transactions database, 
# and therefore a purchase has been made at least once using this card

card_base["in_both"] = card_base['card_number'].isin(transaction_base['credit_card_id'])

card_base
# Out:
#              card_number card_family  credit_limit  cust_id  in_both
# 0    8638-5407-3631-8196     Premium        530000  CC67088     True
# 1    7106-4239-7093-1515        Gold         18000  CC12076     True
# 2    6492-5655-8241-3530     Premium        596000  CC97173     True
# 3    2868-5606-5152-5706        Gold         27000  CC55858     True
# 4    1438-6906-2509-8219    Platinum        142000  CC90518     True
# ..                   ...         ...           ...      ...      ...
# 495  4708-4407-9601-6022     Premium        691000  CC64993     True
# 496  6042-2856-7280-2925        Gold         33000  CC26787     True
# 497  8706-3809-5167-3899     Premium        144000  CC32532     True
# 498  9540-8558-5897-5046     Premium        830000  CC90246     True
# 499  5587-7265-8118-7718        Gold         24000  CC37803     True
#
# [500 rows x 5 columns]

# %%
# now filter card_base for only cards that have `True` in the in_both column, and therefore have made at least one transaction

card_base.loc[card_base["in_both"] == True]
# Out:
#              card_number card_family  credit_limit  cust_id  in_both
# 0    8638-5407-3631-8196     Premium        530000  CC67088     True
# 1    7106-4239-7093-1515        Gold         18000  CC12076     True
# 2    6492-5655-8241-3530     Premium        596000  CC97173     True
# 3    2868-5606-5152-5706        Gold         27000  CC55858     True
# 4    1438-6906-2509-8219    Platinum        142000  CC90518     True
# ..                   ...         ...           ...      ...      ...
# 495  4708-4407-9601-6022     Premium        691000  CC64993     True
# 496  6042-2856-7280-2925        Gold         33000  CC26787     True
# 497  8706-3809-5167-3899     Premium        144000  CC32532     True
# 498  9540-8558-5897-5046     Premium        830000  CC90246     True
# 499  5587-7265-8118-7718        Gold         24000  CC37803     True
#
# [500 rows x 5 columns]

# %% [markdown]
# it looks like all cards have made at least one transaction!

# %% [markdown]
# #### 5. Load `hat_observation`

# %%
hat_observations = pd.read_csv("C:/Users/Kirsty/Documents/GitHub/codeclan_homework_Kirsty/Week_12/Day_03/data/hat_observations.csv").clean_names()

hat_observations
# Out:
#     day  month  year        observation  observation_count
# 0    25     10  2019        black,beret                  7
# 1    11      9  2019       blue,top hat                 10
# 2     4     12  2018    green,santa hat                  9
# 3    18      6  2018        white,beret                  9
# 4    26      9  2018    black,santa hat                  1
# ..  ...    ...   ...                ...                ...
# 95   15      8  2018  purple,bucket hat                  8
# 96   26      1  2018   green,bowler hat                  5
# 97   15     11  2018      black,top hat                  7
# 98   14      9  2019       green,helmet                  4
# 99    1     10  2018        blue,fedora                  4
#
# [100 rows x 5 columns]

# %%
type(hat_observations)
# Out:
# pandas.core.frame.DataFrame

# %%
hat_obs_split = hat_observations["observation"].str.split(",").copy()
hat_obs_split
# Out:
# 0           [black, beret]
# 1          [blue, top hat]
# 2       [green, santa hat]
# 3           [white, beret]
# 4       [black, santa hat]
#               ...
# 95    [purple, bucket hat]
# 96     [green, bowler hat]
# 97        [black, top hat]
# 98         [green, helmet]
# 99          [blue, fedora]
# Name: observation, Length: 100, dtype: object

# %%
# trying to solve this error to save it into a dataframe!

hat_obs_split = hat_observations.loc[hat_observations["observation"].str.split(",").copy()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 hat_obs_split = hat_observations.loc[hat_observations["observation"].str.split(",").copy()]
#
# File C:\tools\Anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\tools\Anaconda3\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# ...

# %% [markdown]
# #### 6. Unite day, month, year

# %%
hat_observations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                100 non-null    int64
#  1   month              100 non-null    int64
#  2   year               100 non-null    int64
#  3   observation        100 non-null    object
#  4   observation_count  100 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 4.0+ KB

# %%
# to be able to unite the 3 columns, they need to be strings

hat_observations[["day", "month", "year"]] = hat_observations[["day", "month", "year"]].astype(str)


hat_observations.info()

type(hat_observations)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day                100 non-null    object
#  1   month              100 non-null    object
#  2   year               100 non-null    object
#  3   observation        100 non-null    object
#  4   observation_count  100 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
# pandas.core.frame.DataFrame

# %%
hat_observations["date"] = hat_observations[["day", "month", "year"]].agg('-'.join, axis=1)

hat_observations
# Out:
#    day month  year        observation  observation_count        date
# 0   25    10  2019        black,beret                  7  25-10-2019
# 1   11     9  2019       blue,top hat                 10   11-9-2019
# 2    4    12  2018    green,santa hat                  9   4-12-2018
# 3   18     6  2018        white,beret                  9   18-6-2018
# 4   26     9  2018    black,santa hat                  1   26-9-2018
# ..  ..   ...   ...                ...                ...         ...
# 95  15     8  2018  purple,bucket hat                  8   15-8-2018
# 96  26     1  2018   green,bowler hat                  5   26-1-2018
# 97  15    11  2018      black,top hat                  7  15-11-2018
# 98  14     9  2019       green,helmet                  4   14-9-2019
# 99   1    10  2018        blue,fedora                  4   1-10-2018
#
# [100 rows x 6 columns]
